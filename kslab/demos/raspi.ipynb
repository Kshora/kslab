# %%
import kslab
from kslab.raspi import *

# %%
kslab.__version__
# Out:
# '1.1.1'

# %%
import os
basepath = "./data/raspi/"
ls = os.listdir(basepath)
ls
# Out:
# ['cu_20230627_213226.csv']

# %%
timepath = "213226"
rasp = Raspi(basepath, timepath)

# %%
rasp.data_config
# Out:
# {'Title': ['ControlUnitADCsignals'],
#  'Date': ['2023-06-2721:32:26'],
#  'Columns': ['date',
#   'time',
#   'IGmode',
#   'IGscale',
#   'QMS_signal',
#   'PresetV1',
#   'PresetV2',
#   'Ip',
#   'Pu',
#   'Pd',
#   'Bu',
#   'Bd',
#   'MFC1',
#   'MFC2',
#   'Ip_c',
#   'Pu_c',
#   'Pd_c',
#   'Bu_c',
#   'Bd_c',
#   'MFC1_c',
#   'MFC2_c'],
#  'Signals': ['Ip', 'Pu', 'Pd', 'Bu', 'Bd', 'MFC1', 'MFC2'],
#  'Channels': ['0', '1', '2', '3', '4', '5', '6']}

# %%
rasp.data
# Out:
#                            date       time  ...    MFC1_c    MFC2_c
# 0    2023-06-27 21:32:26.126105   0.138101  ... -0.003981  0.001991
# 1    2023-06-27 21:32:26.252669   0.264665  ... -0.004135  0.001991
# 2    2023-06-27 21:32:26.378243   0.390239  ... -0.003981  0.001991
# 3    2023-06-27 21:32:26.509551   0.521547  ... -0.004135  0.001991
# 4    2023-06-27 21:32:26.635018   0.647014  ... -0.003522  0.001838
# ..                          ...        ...  ...       ...       ...
# 667  2023-06-27 21:33:51.526121  85.538117  ... -0.002603  0.001991
# 668  2023-06-27 21:33:51.650751  85.662747  ... -0.003522  0.001991
# 669  2023-06-27 21:33:51.778881  85.790877  ... -0.004135  0.001838
# 670  2023-06-27 21:33:51.904092  85.916088  ... -0.003369  0.001991
# 671  2023-06-27 21:33:52.028571  86.040567  ... -0.004288  0.001991
#
# [672 rows x 21 columns]
