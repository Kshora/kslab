# %%
import kslab
from kslab.raspi import *

# %%
kslab.__version__
# Out:
# '1.1.1'

# %%
import os
basepath = "./data/raspi/"
ls = os.listdir(basepath)
ls
# Out:
# ['cu_20230627_213226.csv']

# %%
timepath = "213226"
rasp = Raspi(basepath, timepath)

# %%
rasp.data_config
# Out:
# {'Title': ['ControlUnitADCsignals'],
#  'Date': ['2023-06-2721:32:26'],
#  'Columns': ['date',
#   'time',
#   'IGmode',
#   'IGscale',
#   'QMS_signal',
#   'PresetV1',
#   'PresetV2',
#   'Ip',
#   'Pu',
#   'Pd',
#   'Bu',
#   'Bd',
#   'MFC1',
#   'MFC2',
#   'Ip_c',
#   'Pu_c',
#   'Pd_c',
#   'Bu_c',
#   'Bd_c',
#   'MFC1_c',
#   'MFC2_c'],
#  'Signals': ['Ip', 'Pu', 'Pd', 'Bu', 'Bd', 'MFC1', 'MFC2'],
#  'Channels': ['0', '1', '2', '3', '4', '5', '6']}

# %%
rasp.data
# Out:
#                            date       time  IGmode  IGscale  QMS_signal  \
# 0    2023-06-27 21:32:26.126105   0.138101       0       -3           0
# 1    2023-06-27 21:32:26.252669   0.264665       0       -3           0
# 2    2023-06-27 21:32:26.378243   0.390239       0       -3           0
# 3    2023-06-27 21:32:26.509551   0.521547       0       -3           0
# 4    2023-06-27 21:32:26.635018   0.647014       0       -3           0
# ..                          ...        ...     ...      ...         ...
# 667  2023-06-27 21:33:51.526121  85.538117       0       -7           0
# 668  2023-06-27 21:33:51.650751  85.662747       0       -7           0
# 669  2023-06-27 21:33:51.778881  85.790877       0       -7           0
# 670  2023-06-27 21:33:51.904092  85.916088       0       -7           0
# 671  2023-06-27 21:33:52.028571  86.040567       0       -7           0
#
#      PresetV1  PresetV2        Ip        Pu        Pd  ...      MFC1  \
# ...

# %%
rasp.plot_pressure()

# %%
rasp.plot_pressure(xlabel="date")

# %%
from datetime import datetime
st = datetime(2023,6,27,21,32,30)
et = datetime(2023,6,27,21,33)
rasp.plot_pressure(xlabel="date",st=st,et=et)

# %%
rasp.plot_pressure(xlabel="date",yscale="log")
# Out:
# c:\Users\shora\Anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: AutoMinorLocator does not work with logarithmic scale
#   func(*args, **kwargs)
# c:\Users\shora\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: AutoMinorLocator does not work with logarithmic scale
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
rasp.plot_current()

# %%
rasp.plot_mfc()
